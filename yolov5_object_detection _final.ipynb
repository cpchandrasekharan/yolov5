# %%
# !git clone https://github.com/cpchandrasekharan/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 35, done.
# remote: Counting objects: 100% (35/35), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 35 (delta 13), reused 3 (delta 0), pack-reused 0
# Unpacking objects: 100% (35/35), 6.07 MiB | 4.79 MiB/s, done.

# %%
# !unzip /content/yolov5/yolov5.zip -d /content/yolov5
# Out:
# Archive:  /content/yolov5/yolov5.zip
#    creating: /content/yolov5/yolov5/
#    creating: /content/yolov5/yolov5/yolov5-master/
#   inflating: /content/yolov5/yolov5/yolov5-master/.dockerignore
#   inflating: /content/yolov5/yolov5/yolov5-master/.gitattributes
#    creating: /content/yolov5/yolov5/yolov5-master/.github/
#   inflating: /content/yolov5/yolov5/yolov5-master/.github/dependabot.yml
#    creating: /content/yolov5/yolov5/yolov5-master/.github/ISSUE_TEMPLATE/
#   inflating: /content/yolov5/yolov5/yolov5-master/.github/ISSUE_TEMPLATE/bug-report.yml
#   inflating: /content/yolov5/yolov5/yolov5-master/.github/ISSUE_TEMPLATE/config.yml
#   inflating: /content/yolov5/yolov5/yolov5-master/.github/ISSUE_TEMPLATE/feature-request.yml
#   inflating: /content/yolov5/yolov5/yolov5-master/.github/ISSUE_TEMPLATE/question.yml
#   inflating: /content/yolov5/yolov5/yolov5-master/.github/PULL_REQUEST_TEMPLATE.md
#    creating: /content/yolov5/yolov5/yolov5-master/.github/workflows/
# ...

# %%
# %cd /content/yolov5/yolov5/yolov5-master
# Out:
# /content/yolov5/yolov5/yolov5-master

# %%
# !pip3 install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 KB 13.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 9.4 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# Mounted at /content/gdrive
# ' 0.jpg'
#  0_KL005425412201920E.pdf
# '10 std second mid term marks.xlsx'
#  1.ml
# '1st_week questions.gdoc'
#  20190801_123206.jpg
#  20200919_095324.jpg
#  20200927_143355.jpg
#  20201211_103358.jpg
# 'Action Detection Tutorial-final.ipynb'
#  action.h5
# 'A I.gslides'
#  android_figurine
# 'App Development .docx'
#  Arduimo-1.gslides
# 'Arduino Basics.gslides'
# 'Arduino course material 2 .gdoc'
# 'Arduino course material.gdoc'
# 'Arduino & Pi.gslides'
#  Aruundathi
#  Assignment.pdf
# 'assignment Rootally AI.py'
# 'attendance _WMOC_2023.gsheet'
#  b941f3dd137e45f69dd228f37ae2f013-policy.pdf
# 'Basics of electricty.gslides'
# 'Benefits of using TensorFlow.gdoc'
#  Bias_Variance.gslides
# 'bike insurance.pdf'
# 'Blank Quiz (10).gform'
# 'Blank Quiz (11).gform'
# 'Blank Quiz (1).gform'
# 'Blank Quiz (2).gform'
# 'Blank Quiz (3).gform'
# 'Blank Quiz (4).gform'
# 'Blank Quiz (5).gform'
# 'Blank Quiz (6).gform'
# 'Blank Quiz (7).gform'
# ...

# %%
# !unzip /content/gdrive/MyDrive/dataset.zip -d /content/yolov5/yolov5
# Out:
# Archive:  /content/gdrive/MyDrive/dataset.zip
#    creating: /content/yolov5/yolov5/dataset/
#    creating: /content/yolov5/yolov5/dataset/images/
#    creating: /content/yolov5/yolov5/dataset/images/train/
#   inflating: /content/yolov5/yolov5/dataset/images/train/IMG20221129100345.jpg
#   inflating: /content/yolov5/yolov5/dataset/images/train/IMG20221129100356.jpg
#   inflating: /content/yolov5/yolov5/dataset/images/train/IMG20221129100407.jpg
#   inflating: /content/yolov5/yolov5/dataset/images/train/IMG20221129100428.jpg
#   inflating: /content/yolov5/yolov5/dataset/images/train/IMG20221129100449.jpg
#   inflating: /content/yolov5/yolov5/dataset/images/train/IMG20221129100521.jpg
#   inflating: /content/yolov5/yolov5/dataset/images/train/IMG20221129100534.jpg
#   inflating: /content/yolov5/yolov5/dataset/images/train/IMG20221129100601.jpg
#   inflating: /content/yolov5/yolov5/dataset/images/train/IMG20221129100616.jpg
# ...

# %%
# !python3 /content/yolov5/yolov5/yolov5-master/train.py --img 416 --batch 16 --epochs 60 --data /content/yolov5/yolov5/yolov5-master/data.yaml --weights yolov5s.pt
# Out:
# 2023-04-06 01:09:16.781278: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-06 01:09:17.898336: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...

# %%
#!python detect.py --weights runs/train/coffee_cherry/weights/best.pt --img 416 --conf 0.25 --source runs/train/coffee_cherry/video_1.mp4

# %%
# !python detect.py --weights runs/train/coffee_cherry/weights/best.pt --img 416 --conf 0.25 --source runs/train/coffee_cherry/video_1.mp4

# %%
# Convert weights to fp16 TFLite model

# !python export.py --weights runs/train/exp2/weights/best.pt --include tflite --img 416
# Out:
# export: data=data/coco128.yaml, weights=['runs/train/exp2/weights/best.pt'], imgsz=[416], batch_size=1, device=cpu, half=False, inplace=False, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=17, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['tflite']
# YOLOv5 🚀 2023-3-27 Python-3.9.16 torch-2.0.0+cu118 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7023610 parameters, 0 gradients, 15.8 GFLOPs
#
# PyTorch: starting from runs/train/exp2/weights/best.pt with output shape (1, 10647, 10) (13.7 MB)
# 2023-04-06 01:43:18.635904: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
